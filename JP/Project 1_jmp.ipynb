# %%
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Filepath
filepath = "Attributes_DataFrame.csv"

# Read csv
df = pd.read_csv(filepath)
df.head(30)
# Out:
#                                                 Title   Domestic  \
# 0                               Jurassic World (2015)  652270625
# 1   Star Wars: Episode VII - The Force Awakens (2015)  936662225
# 2                      Avengers: Age of Ultron (2015)  459005868
# 3                                   Inside Out (2015)  356461711
# 4                                    Furious 7 (2015)  353007020
# 5                              American Sniper (2014)  350126372
# 6                                      Minions (2015)  336045770
# 7        The Hunger Games: Mockingjay - Part 2 (2015)  281723902
# 8                                  The Martian (2015)  228433663
# 9                                   Cinderella (2015)  201151353
# 10              How the Grinch Stole Christmas (2000)  260044825
# 11                      Mission: Impossible II (2000)  215409889
# 12                                   Gladiator (2000)  187705427
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          3400 non-null   object
#  1   Domestic       3400 non-null   int64
#  2   International  3400 non-null   int64
#  3   Budget         2307 non-null   float64
#  4   Distributor    3399 non-null   object
#  5   MPAA-Rating    3244 non-null   object
#  6   Runtime        3400 non-null   int64
#  7   Genres         3397 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 212.6+ KB

# %%
df.tail(10)
# Out:
#                                                   Title  Domestic  \
# 3390                         Wild Mountain Thyme (2020)    213440
# 3391                         The Secrets We Keep (2020)    207928
# 3392  Fate/Stay Night: Heaven's Feel - III. Spring S...    200000
# 3393                                     Ashfall (2019)    372562
# 3394   National Theater Live: Cyrano de Bergerac (2020)    198352
# 3395                     The Wolf of Snow Hollow (2020)    185026
# 3396                                   Come Away (2020)    184477
# 3397                                   No Escape (2020)    167962
# 3398                               A Call to Spy (2020)    159014
# 3399                                  Love Story (2020)    153504
#
#       International  Budget               Distributor MPAA-Rating  Runtime  \
# 3390        1257414     NaN     Bleecker Street Media       PG-13      102
# 3391         407185     NaN     Bleecker Street Media           R       97
# ...

# %%
# Create 2 new columns: num_genre (split on semicolon, get length of list), main_genre (split on ; return the first genre in the list)

# dropping additional dramas --LIMFAC
# Create column called total_rev (domestic and international)
# drop na values in budget
# title-- 2 columns: title without year.  title.split on left perinthese. year: split on perinthese and take the year. Cast to int.

# probably drop nulls.
